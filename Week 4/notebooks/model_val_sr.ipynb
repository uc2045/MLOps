# %% [markdown]
# ## Algorithm training, testing, and validation

# %%
# import libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
sns.set() # Revert to matplotlib defaults
plt.rcParams['figure.figsize'] = (16, 12)

# %%
# load clean dataset
cleaned_df= pd.read_csv('~/Downloads/Omdena/MLOps/solcast_project/datasets/cleaned/cleaned_solar_irradiation.csv')
cleaned_df.head()
# Out:
#    Unnamed: 0  MonthPE        Date  Daily_Temp  Daily_Precip  Daily_Humidity  \
# 0  2018-12-31       12  2018-12-31   11.440000      6.850000       63.600000
# 1  2019-01-01        1  2019-01-01    8.627273     10.709091       67.909091
# 2  2019-01-02        1  2019-01-02    3.436364     31.627273       94.909091
# 3  2019-01-03        1  2019-01-03    6.518182     15.536364       79.272727
# 4  2019-01-04        1  2019-01-04   11.209091      8.990909       48.818182
#
#    Daily_Pressure  Daily_WindDir  Daily_WindSpeed   Daily_DNI   Daily_DHI  \
# 0      986.080000     257.800000         5.160000  310.500000  162.600000
# 1      994.736364      36.454545         5.445455   16.272727  116.454545
# 2      993.781818       8.090909         5.081818    0.000000   32.545455
# 3      989.736364     283.545455         5.263636  238.272727  125.454545
# 4      990.590909     301.909091         3.900000  720.000000   49.727273
#
#    Daily_radiation
# 0       305.000000
# 1       119.272727
# 2        32.545455
# 3       219.181818
# 4       364.545455

# %%
# display column names
cleaned_df.columns
# Out:
# Index(['Unnamed: 0', 'MonthPE', 'Date', 'Daily_Temp', 'Daily_Precip',
#        'Daily_Humidity', 'Daily_Pressure', 'Daily_WindDir', 'Daily_WindSpeed',
#        'Daily_DNI', 'Daily_DHI', 'Daily_radiation'],
#       dtype='object')

# %%
# select features
cleaned_df= cleaned_df[['MonthPE', 'Date', 'Daily_Temp', 'Daily_Precip', 'Daily_Humidity', 'Daily_Pressure',\
                        'Daily_WindDir', 'Daily_WindSpeed', 'Daily_DNI', 'Daily_DHI', 'Daily_radiation']]

# %%
# Feature Engineering of Time Series Column
cleaned_df['Date'] = pd.to_datetime(cleaned_df['Date'], format='%Y-%m-%d')
cleaned_df['year'] = cleaned_df['Date'].dt.year
cleaned_df['month'] = cleaned_df['Date'].dt.month
cleaned_df['day'] = cleaned_df['Date'].dt.day

# %%
# display column names
cleaned_df.columns
# Out:
# Index(['MonthPE', 'Date', 'Daily_Temp', 'Daily_Precip', 'Daily_Humidity',
#        'Daily_Pressure', 'Daily_WindDir', 'Daily_WindSpeed', 'Daily_DNI',
#        'Daily_DHI', 'Daily_radiation', 'year', 'month', 'day'],
#       dtype='object')

# %%
# select features
cleaned_df = cleaned_df[['month', 'day', 'Daily_Temp', 'Daily_Precip', 'Daily_Humidity',
       'Daily_Pressure', 'Daily_WindDir', 'Daily_WindSpeed', 'Daily_DNI',
       'Daily_DHI', 'Daily_radiation']]
cleaned_df.head()
# Out:
#    month  day  Daily_Temp  Daily_Precip  Daily_Humidity  Daily_Pressure  \
# 0     12   31   11.440000      6.850000       63.600000      986.080000
# 1      1    1    8.627273     10.709091       67.909091      994.736364
# 2      1    2    3.436364     31.627273       94.909091      993.781818
# 3      1    3    6.518182     15.536364       79.272727      989.736364
# 4      1    4   11.209091      8.990909       48.818182      990.590909
#
#    Daily_WindDir  Daily_WindSpeed   Daily_DNI   Daily_DHI  Daily_radiation
# 0     257.800000         5.160000  310.500000  162.600000       305.000000
# 1      36.454545         5.445455   16.272727  116.454545       119.272727
# 2       8.090909         5.081818    0.000000   32.545455        32.545455
# 3     283.545455         5.263636  238.272727  125.454545       219.181818
# 4     301.909091         3.900000  720.000000   49.727273       364.545455

# %% [markdown]
# ## Model training and testing

# %%
# import libraries for algorithms traininng, and metrics to judge performance
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# produces a 70%, 15%, 15% split for training, validation and test sets
train_data, validation_data, test_data = np.split(cleaned_df.sample(frac = 1), [int(.7 * len(cleaned_df)), int(.85 * len(cleaned_df))])

# convert dataframes to .csv and save locally
train_data.to_csv('~/Downloads/Omdena/MLOps/solcast_project/datasets/cleaned/train.csv', header = True, index = False)
validation_data.to_csv('~/Downloads/Omdena/MLOps/solcast_project/datasets/cleaned/validation.csv', header=True, index = False)
test_data.to_csv('~/Downloads/Omdena/MLOps/solcast_project/datasets/cleaned/test.csv', header = True, index = False)

# %%
# training data
train_df = pd.read_csv('~/Downloads/Omdena/MLOps/solcast_project/datasets/cleaned/train.csv')
X_train = train_df.drop(['Daily_radiation'], axis = 1)
y_train = train_df['Daily_radiation']

# test data
test_df = pd.read_csv('~/Downloads/Omdena/MLOps/solcast_project/datasets/cleaned/test.csv')
X_test = test_df.drop(['Daily_radiation'], axis = 1)
y_test = test_df['Daily_radiation']

# %% [markdown]
# ## Linear Regression

# %%
# Setup the pipeline steps for linear regression
steps = [('scaler', StandardScaler()), ('lr', LinearRegression())]
# Create the pipeline
pipeline_lr = Pipeline(steps)
# Fit the pipeline to the train set
pipeline_lr.fit(X_train, y_train)
# Predict the labels of the test set
y_pred_lr = pipeline_lr.predict(X_test)

# %%
# Evaluating algorithm performance
mse = mean_squared_error(y_test, y_pred_lr, squared = False)

mae = mean_absolute_error(y_test, y_pred_lr)

print('r2_score: ', r2_score(y_test, y_pred_lr))

print('Root Mean Squared Error: %.2f' % np.sqrt(mse))

print('Root Mean Absolute Error: %.2f' % np.sqrt(mae))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-b61caf6954b4> in <module>
#       1 # Evaluating algorithm performance
# ----> 2 mse = mean_squared_error(y_test, y_pred_lr, squared = False)
#       3
#       4 mae = mean_absolute_error(y_test, y_pred_lr)
#       5
#
# TypeError: mean_squared_error() got an unexpected keyword argument 'squared'

# %%
# Run the model against the test data presented through a plot
fig, pX = plt.subplots()

pX.scatter(y_test, y_pred_lr, edgecolors = (0, 0, 0))
pX.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'm--', lw = 3)
pX.set_xlabel('Actual solar irradiation')
pX.set_ylabel('Predicted solar irradiation')
pX.set_title(" Linear regression: Verified vs Predicted solar irradiation")
plt.show()

# %%
sns.jointplot(y_test, y_pred_lr, kind = 'reg')
plt.show()

# %% [markdown]
# ## Random Forest Regressor

# %%
# Setup the pipeline steps for random forest: steps
steps = [('scaler', StandardScaler()), ('rfr', RandomForestRegressor())]
# Create the pipeline: pipeline
pipeline_rfr = Pipeline(steps)
# Fit the pipeline to the train set
pipeline_rfr.fit(X_train, y_train)
# Predict the labels of the test set
y_pred_rfr = pipeline_rfr.predict(X_test)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
# Evaluating algorithm performance
mse_rf = mean_squared_error(y_test, y_pred_rfr, squared = False)

mae_rf = mean_absolute_error(y_test, y_pred_rfr)

print('r2_score: ', r2_score(y_test, y_pred_rfr))

print('Root Mean Squared Error: %.2f' % np.sqrt(mse_rf))

print('Root Mean Absolute Error: %.2f' % np.sqrt(mae_rf))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-98f1f5d9a829> in <module>
#       1 # Evaluating algorithm performance
# ----> 2 mse_rf = mean_squared_error(y_test, y_pred_rfr, squared = False)
#       3
#       4 mae_rf = mean_absolute_error(y_test, y_pred_rfr)
#       5
#
# TypeError: mean_squared_error() got an unexpected keyword argument 'squared'

# %%
# Run the model against the test data presented through a plot
fig, pX = plt.subplots()

pX.scatter(y_test, y_pred_rfr, edgecolors = (0, 0, 0))
pX.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'm--', lw = 3)
pX.set_xlabel('Actual solar irradiation')
pX.set_ylabel('Predicted solar irradiation')
pX.set_title(" Random Forest: Verified vs Predicted solar irradiation")
plt.show()

# %%
sns.jointplot(y_test, y_pred_rfr, kind = 'reg')
plt.show()

# %% [markdown]
# ## GradientBoosting Regressor

# %%
# Setup the pipeline steps: steps
steps = [('scaler', StandardScaler()), ('gbr', GradientBoostingRegressor())]
# Create the pipeline: pipeline
pipeline_gbr = Pipeline(steps)
# Fit the pipeline to the train set
pipeline_gbr.fit(X_train, y_train)
# Predict the labels of the test set
y_pred_gbr = pipeline_gbr.predict(X_test)

# %%
# Evaluating algorithm performance
mse_gr = mean_squared_error(y_test, y_pred_gbr, squared = False)

mae_gr = mean_absolute_error(y_test, y_pred_gbr)

print('r2_score: ', r2_score(y_test, y_pred_gbr))

print('Root Mean Squared Error: %.2f' % np.sqrt(mse_gr))

print('Root Mean Absolute Error: %.2f' % np.sqrt(mae_gr))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-22-33d1c7ff54ff> in <module>
#       1 # Evaluating algorithm performance
# ----> 2 mse_gr = mean_squared_error(y_test, y_pred_gbr, squared = False)
#       3
#       4 mae_gr = mean_absolute_error(y_test, y_pred_gbr)
#       5
#
# TypeError: mean_squared_error() got an unexpected keyword argument 'squared'

# %%
# Run the model against the test data presented through a plot
fig, pX = plt.subplots()

pX.scatter(y_test, y_pred_gbr, edgecolors = (0, 0, 0))
pX.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], 'm--', lw = 3)
pX.set_xlabel('Actual solar irradiation')
pX.set_ylabel('Predicted solar irradiation')
pX.set_title(" Gradient Boost: Verified vs Predicted solar irradiation")
plt.show()

# %%
sns.jointplot(y_test, y_pred_gbr, kind = 'reg')
plt.show()

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.21.3

# %% [markdown]
# ## Model Validation

# %%
# validation data
val_df = pd.read_csv('~/Downloads/Omdena/MLOps/solcast_project/datasets/cleaned/validation.csv')
X_val = val_df.drop(['Daily_radiation'], axis = 1)
y_val = val_df['Daily_radiation']

# %%
y_val_lr = pipeline_lr.predict(X_val)
y_val_rfr = pipeline_rfr.predict(X_val)
y_val_gbr = pipeline_gbr.predict(X_val)

# %%
# Evaluating algorithm performance for linear regression
mse_lr_val = mean_squared_error(y_val, y_val_lr, squared = False)

mae_lr_val = mean_absolute_error(y_val, y_val_lr)

print('r2_score', r2_score(y_val, y_val_lr))

print('Linear Regression - Root Mean Squared Error: %.2f' % np.sqrt(mse_lr_val))

print('Linear Regression - Root Mean Absolute Error: %.2f' % np.sqrt(mse_lr_val))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-9c5b8e8c7215> in <module>
#       1 # Evaluating algorithm performance for linear regression
# ----> 2 mse_lr_val = mean_squared_error(y_val, y_val_lr, squared = False)
#       3
#       4 mae_lr_val = mean_absolute_error(y_val, y_val_lr)
#       5
#
# TypeError: mean_squared_error() got an unexpected keyword argument 'squared'

# %%
# Evaluating algorithm performance for random forest regression
mse_rf_val = mean_squared_error(y_val, y_val_rfr, squared = False)

mae_rf_val = mean_absolute_error(y_val, y_val_rfr)

print('r2_score', r2_score(y_val, y_val_rfr))

print('Random Forest - Root Mean Squared Error: %.2f' % np.sqrt(mse_rf_val))

print('Random Forest - Root Mean Absolute Error: %.2f' % np.sqrt(mse_rf_val))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-70d1ec705328> in <module>
#       1 # Evaluating algorithm performance for random forest regression
# ----> 2 mse_rf_val = mean_squared_error(y_val, y_val_rfr, squared = False)
#       3
#       4 mae_rf_val = mean_absolute_error(y_val, y_val_rfr)
#       5
#
# TypeError: mean_squared_error() got an unexpected keyword argument 'squared'

# %%
# Evaluating algorithm performance for gradient boost regression
mse_gbr_val = mean_squared_error(y_val, y_val_gbr, squared = False)

mae_gbr_val = mean_absolute_error(y_val, y_val_gbr)

print('r2_score', r2_score(y_val, y_val_gbr))

print('Gradient Boost - Root Mean Squared Error: %.2f' % np.sqrt(mse_gbr_val))

print('Gradient Boost - Root Mean Absolute Error: %.2f' % np.sqrt(mae_gbr_val))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-2427b597a9f3> in <module>
#       1 # Evaluating algorithm performance for gradient boost regression
# ----> 2 mse_gbr_val = mean_squared_error(y_val, y_val_gbr, squared = False)
#       3
#       4 mae_gbr_val = mean_absolute_error(y_val, y_val_gbr)
#       5
#
# TypeError: mean_squared_error() got an unexpected keyword argument 'squared'

# %%
## Export model and hook it with api

# %% [markdown]
# ## Experiment tracking with neptune

# %%
# Terminal
# pip install neptune-notebooks
# jupyter nbextension enable --py neptune-notebooks
# pip install neptune-client
# pip install neptune-sklearn

# %%
# import neptune libraries and sklearn integration
import neptune.new as neptune
import neptune.new.integrations.sklearn as npt_utils

run = neptune.init(api_token = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI2YmI4YTc1Ni0wMDVlLTQ3ZjQtOWYxNy02MWZlNTc0OTYzMzAifQ==",
                   project = "uc2045/solcast",
                   name = 'solar-irradiation',
                   source_files = ["model_dev_sr.ipynb"])
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-34-c035913ff477> in <module>
#       1 # import neptune libraries and sklearn integration
# ----> 2 import neptune.new as neptune
#       3 import neptune.new.integrations.sklearn as npt_utils
#       4
#       5 run = neptune.init(api_token = "eyJhcGlfYWRkcmVzcyI6Imh0dHBzOi8vYXBwLm5lcHR1bmUuYWkiLCJhcGlfdXJsIjoiaHR0cHM6Ly9hcHAubmVwdHVuZS5haSIsImFwaV9rZXkiOiI2YmI4YTc1Ni0wMDVlLTQ3ZjQtOWYxNy02MWZlNTc0OTYzMzAifQ==",
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/__init__.py in <module>
#      25     NeptuneIncorrectImportException,
#      26 )
# ---> 27 from neptune.internal.api_clients import backend_factory
#      28 from neptune.internal.api_clients.offline_backend import OfflineBackend
#      29 from neptune.internal.backends.hosted_neptune_backend import HostedNeptuneBackend
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/internal/api_clients/__init__.py in <module>
#      15 #
#      16
# ---> 17 from neptune.internal.api_clients.hosted_api_clients.hosted_backend_api_client import (
#      18     HostedNeptuneBackendApiClient,
#      19 )
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/internal/api_clients/hosted_api_clients/hosted_backend_api_client.py in <module>
#      38 )
#      39 from neptune.internal.api_clients.credentials import Credentials
# ---> 40 from neptune.internal.api_clients.hosted_api_clients.hosted_alpha_leaderboard_api_client import (
#      41     HostedAlphaLeaderboardApiClient,
#      42 )
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/internal/api_clients/hosted_api_clients/hosted_alpha_leaderboard_api_client.py in <module>
#      56     NeptuneException,
#      57 )
# ---> 58 from neptune.experiments import Experiment
#      59 from neptune.internal.channels.channels import (
#      60     ChannelNamespace,
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/experiments.py in <module>
#      34 )
#      35 from neptune.internal.channels.channels_values_sender import ChannelsValuesSender
# ---> 36 from neptune.internal.execution.execution_context import ExecutionContext
#      37 from neptune.internal.utils.image import get_image_content
#      38 from neptune.utils import align_channels_on_x, is_float, is_nan_or_inf
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/internal/execution/execution_context.py in <module>
#      32     StdErrWithUpload,
#      33 )
# ---> 34 from neptune.internal.threads.aborting_thread import AbortingThread
#      35 from neptune.internal.threads.hardware_metric_reporting_thread import (
#      36     HardwareMetricReportingThread,
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/internal/threads/aborting_thread.py in <module>
#      19
#      20 from neptune.internal.threads.neptune_thread import NeptuneThread
# ---> 21 from neptune.internal.websockets.message import MessageType
#      22 from neptune.internal.websockets.websocket_message_processor import (
#      23     WebsocketMessageProcessor,
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/internal/websockets/message.py in <module>
#      14 # limitations under the License.
#      15 #
# ---> 16 from neptune.new.attributes.constants import SIGNAL_TYPE_ABORT, SIGNAL_TYPE_STOP
#      17
#      18
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/__init__.py in <module>
#      33     NeptunePossibleLegacyUsageException,
#      34 )
# ---> 35 from neptune.new.run import Run
#      36 from neptune.new.internal.init_impl import (
#      37     __version__,
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/run.py in <module>
#      18 import click
#      19
# ---> 20 from neptune.new.attribute_container import AttributeContainer
#      21 from neptune.new.internal.backends.neptune_backend import NeptuneBackend
#      22 from neptune.new.internal.background_job import BackgroundJob
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/attribute_container.py in <module>
#      28
#      29 from neptune.exceptions import UNIX_STYLES
# ---> 30 from neptune.new.attributes import create_attribute_from_type
#      31 from neptune.new.attributes.attribute import Attribute
#      32 from neptune.new.attributes.namespace import (
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/attributes/__init__.py in <module>
#      15 #
#      16
# ---> 17 from .atoms.artifact import Artifact
#      18 from .atoms.float import Float
#      19 from .atoms.string import String
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/attributes/atoms/__init__.py in <module>
#      15 #
#      16
# ---> 17 from .float import Float
#      18 from .file import File
#      19 from .string import String
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/attributes/atoms/float.py in <module>
#      16 import typing
#      17
# ---> 18 from neptune.new.attributes.atoms.copiable_atom import CopiableAtom
#      19 from neptune.new.internal.container_type import ContainerType
#      20 from neptune.new.internal.operation import AssignFloat
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/attributes/atoms/copiable_atom.py in <module>
#      17 import typing
#      18
# ---> 19 from neptune.new.attributes.atoms.atom import Atom
#      20 from neptune.new.internal.container_type import ContainerType
#      21 from neptune.new.internal.operation import CopyAttribute
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/attributes/atoms/atom.py in <module>
#      14 # limitations under the License.
#      15 #
# ---> 16 from neptune.new.attributes.attribute import Attribute
#      17
#      18
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/attributes/attribute.py in <module>
#      16 from typing import List, TYPE_CHECKING
#      17
# ---> 18 from neptune.new.internal.backends.neptune_backend import NeptuneBackend
#      19
#      20 from neptune.new.internal.operation import Operation
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/internal/backends/neptune_backend.py in <module>
#      18
#      19 from neptune.new.exceptions import NeptuneException
# ---> 20 from neptune.new.internal.artifacts.types import ArtifactFileData
#      21 from neptune.new.internal.backends.api_model import (
#      22     ApiRun,
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/internal/artifacts/__init__.py in <module>
#      14 # limitations under the License.
#      15 #
# ---> 16 from .drivers import *
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/internal/artifacts/drivers/__init__.py in <module>
#      14 # limitations under the License.
#      15 #
# ---> 16 from .s3 import S3ArtifactDriver
#      17 from .local import LocalArtifactDriver
#
# /opt/anaconda3/lib/python3.7/site-packages/neptune/new/internal/artifacts/drivers/s3.py in <module>
#      19 from urllib.parse import urlparse
#      20
# ---> 21 import boto3
#      22 from botocore.exceptions import NoCredentialsError
#      23
#
# /opt/anaconda3/lib/python3.7/site-packages/boto3/__init__.py in <module>
#      14 import logging
#      15
# ---> 16 from boto3.session import Session
#      17 from boto3.compat import _warn_deprecated_python
#      18
#
# /opt/anaconda3/lib/python3.7/site-packages/boto3/session.py in <module>
#      15 import os
#      16
# ---> 17 import botocore.session
#      18 from botocore.client import Config
#      19 from botocore.exceptions import DataNotFoundError, UnknownServiceError
#
# /opt/anaconda3/lib/python3.7/site-packages/botocore/session.py in <module>
#      27 from botocore import UNSIGNED
#      28 import botocore.configloader
# ---> 29 import botocore.credentials
#      30 import botocore.client
#      31 from botocore.configprovider import ConfigValueStore
#
# /opt/anaconda3/lib/python3.7/site-packages/botocore/credentials.py in <module>
#      33 from botocore.compat import total_seconds
#      34 from botocore.compat import compat_shell_split
# ---> 35 from botocore.config import Config
#      36 from botocore.exceptions import UnknownCredentialError
#      37 from botocore.exceptions import PartialCredentialsError
#
# /opt/anaconda3/lib/python3.7/site-packages/botocore/config.py in <module>
#      14 from botocore.compat import OrderedDict
#      15
# ---> 16 from botocore.endpoint import DEFAULT_TIMEOUT, MAX_POOL_CONNECTIONS
#      17 from botocore.exceptions import InvalidS3AddressingStyleError
#      18 from botocore.exceptions import InvalidRetryConfigurationError
#
# /opt/anaconda3/lib/python3.7/site-packages/botocore/endpoint.py in <module>
#      20 from botocore.vendored import six
#      21
# ---> 22 from botocore.awsrequest import create_request_object
#      23 from botocore.exceptions import HTTPClientError
#      24 from botocore.httpsession import URLLib3Session
#
# /opt/anaconda3/lib/python3.7/site-packages/botocore/awsrequest.py in <module>
#      22 from urllib3.connectionpool import HTTPSConnectionPool
#      23
# ---> 24 import botocore.utils
#      25 from botocore.compat import six
#      26 from botocore.compat import (
#
# /opt/anaconda3/lib/python3.7/site-packages/botocore/utils.py in <module>
#      30 import botocore
#      31 import botocore.awsrequest
# ---> 32 import botocore.httpsession
#      33 from botocore.compat import (
#      34     json, quote, zip_longest, urlsplit, urlunsplit, OrderedDict,
#
# /opt/anaconda3/lib/python3.7/site-packages/botocore/httpsession.py in <module>
#       8 from urllib3 import PoolManager, proxy_from_url, Timeout
#       9 from urllib3.util.retry import Retry
# ---> 10 from urllib3.util.ssl_ import (
#      11     ssl, OP_NO_SSLv2, OP_NO_SSLv3, OP_NO_COMPRESSION,
#      12     PROTOCOL_TLS, DEFAULT_CIPHERS,
#
# ImportError: cannot import name 'PROTOCOL_TLS' from 'urllib3.util.ssl_' (/opt/anaconda3/lib/python3.7/site-packages/urllib3/util/ssl_.py)
